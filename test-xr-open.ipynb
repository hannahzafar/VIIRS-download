# %%
import xarray as xr
import glob

# %%
# !ls VNP43IA4_V002_2020-01-01_2020-01-01 | head -n 1
# Out:
# VNP43IA4.A2020001.h00v08.002.2024060175618.h5
# ls: write error: Broken pipe

# %%
file = "VNP43IA4_V002_2020-01-01_2020-01-01/VNP43IA4.A2020001.h00v08.002.2024060175618.h5"

# %%
xr.open_dataset(file, group='/HDFEOS/GRIDS/VIIRS_Grid_BRDF/Data Fields',
                phony_dims="access",
                engine="h5netcdf")
# Out:
# <xarray.Dataset> Size: 207MB
# Dimensions:                                (YDim: 2400, XDim: 2400,
#                                             phony_dim_0: 1)
# Dimensions without coordinates: YDim, XDim, phony_dim_0
# Data variables:
#     BRDF_Albedo_Band_Mandatory_Quality_I1  (YDim, XDim) float32 23MB ...
#     BRDF_Albedo_Band_Mandatory_Quality_I2  (YDim, XDim) float32 23MB ...
#     BRDF_Albedo_Band_Mandatory_Quality_I3  (YDim, XDim) float32 23MB ...
#     Nadir_Reflectance_I1                   (YDim, XDim) float64 46MB ...
#     Nadir_Reflectance_I2                   (YDim, XDim) float64 46MB ...
#     Nadir_Reflectance_I3                   (YDim, XDim) float64 46MB ...
#     Projection                             (phony_dim_0) int32 4B ...

# %%
files = glob.glob("VNP43IA4_V002_2020-01-01_2020-01-01/*.h5")
files = files[:5]

# %%
xr.open_mfdataset(files, 
                  group='/HDFEOS/GRIDS/VIIRS_Grid_BRDF/Data Fields', 
                  phony_dims="access",
                  combine="nested",
                  compat="override",
                  engine="h5netcdf",
                 )
# Out:
# <xarray.Dataset> Size: 207MB
# Dimensions:                                (YDim: 2400, XDim: 2400,
#                                             phony_dim_0: 1)
# Dimensions without coordinates: YDim, XDim, phony_dim_0
# Data variables:
#     BRDF_Albedo_Band_Mandatory_Quality_I1  (YDim, XDim) float32 23MB dask.array<chunksize=(100, 2400), meta=np.ndarray>
#     BRDF_Albedo_Band_Mandatory_Quality_I2  (YDim, XDim) float32 23MB dask.array<chunksize=(100, 2400), meta=np.ndarray>
#     BRDF_Albedo_Band_Mandatory_Quality_I3  (YDim, XDim) float32 23MB dask.array<chunksize=(100, 2400), meta=np.ndarray>
#     Nadir_Reflectance_I1                   (YDim, XDim) float64 46MB dask.array<chunksize=(100, 2400), meta=np.ndarray>
#     Nadir_Reflectance_I2                   (YDim, XDim) float64 46MB dask.array<chunksize=(100, 2400), meta=np.ndarray>
#     Nadir_Reflectance_I3                   (YDim, XDim) float64 46MB dask.array<chunksize=(100, 2400), meta=np.ndarray>
# ...
